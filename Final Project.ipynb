# %%
'''
Rong Jiang, No collaboartion, No extension
This project is to do a linear regression on the dataset and 
predict the medical amount by entering random value for each variable
'''
import numpy as np # linear algebra
import pandas as pd # data processing
import seaborn as sns 
import matplotlib.pyplot as plt
from joblib import dump, load

file = 'insurance.csv'
data= pd.read_csv(file)

# %%
#Data Collection

# %%
data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
#Read the dataset
#print first 10 rows in dataframe
data.head(10)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# 5   31  female  25.740         0     no  southeast   3756.62160
# 6   46  female  33.440         1     no  southeast   8240.58960
# 7   37  female  27.740         3     no  northwest   7281.50560
# 8   37    male  29.830         2     no  northeast   6406.41070
# 9   60  female  25.840         0     no  northwest  28923.13692

# %%
#print tail 10 rows in dataframe
data.tail(10)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 1328   23  female  24.225         2     no  northeast  22395.74424
# 1329   52    male  38.600         2     no  southwest  10325.20600
# 1330   57  female  25.740         2     no  southeast  12629.16560
# 1331   23  female  33.400         0     no  southwest  10795.93733
# 1332   52  female  44.700         3     no  southwest  11411.68500
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030

# %%
# Print the Number of Rows and Columns
data.shape
# Out:
# (1338, 7)

# %%
#Explore the dataframe
#getting some basic information about dataframe
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
#View the statistical measure of data
data.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
# Check if there exists missing value
data.isnull()
# Out:
#         age    sex    bmi  children  smoker  region  charges
# 0     False  False  False     False   False   False    False
# 1     False  False  False     False   False   False    False
# 2     False  False  False     False   False   False    False
# 3     False  False  False     False   False   False    False
# 4     False  False  False     False   False   False    False
# ...     ...    ...    ...       ...     ...     ...      ...
# 1333  False  False  False     False   False   False    False
# 1334  False  False  False     False   False   False    False
# 1335  False  False  False     False   False   False    False
# 1336  False  False  False     False   False   False    False
# 1337  False  False  False     False   False   False    False
#
# [1338 rows x 7 columns]

# %%
# Check the sum of missing value
data.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
#Data visualization of Numercial Variables
#1. Distribution of Age
sns.set()
plt.figure(figsize=(10,10))
sns.displot(data['age'])
plt.title('Distribution of Age')
plt.show()

# %%
sns.scatterplot(x='age', y = 'charges', data = data)
plt.show()

# %%
#2. Distribution of BMI
plt.figure(figsize=(10,10))
sns.displot(data['bmi'])
plt.title('Distribution of BMI')
plt.show()

# %%
sns.scatterplot(x='bmi', y = 'charges', data = data)
plt.show()

# %%
#3. Distribution of Children
plt.figure(figsize=(10,10))
sns.displot(data['children'])
plt.title('Distribution of Children')
plt.show()

# %%
sns.scatterplot(x='children', y = 'charges', data = data)
plt.show()

# %%
data['children'].value_counts()
# Out:
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64

# %%
#4. Distribution of Charges
plt.figure(figsize=(10,10))
sns.displot(data['charges'])
plt.title('Distribution of Charges')
plt.show()

# %%
#2. Sex
plt.figure(figsize=(5,5))
sns.countplot(data['sex'])
plt.title('Sex')
plt.show()
# Out:
# /Users/Hanna/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(x = 'sex', y = 'charges', data = data)
plt.show()

# %%
data['sex'].value_counts()
# Out:
# male      676
# female    662
# Name: sex, dtype: int64

# %%
#3. Smoker
plt.figure(figsize=(5,5))
sns.countplot(data['smoker'])
plt.title('Smoker')
plt.show()
# Out:
# /Users/Hanna/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(x = 'smoker', y = 'charges', data = data)
plt.show()

# %%
data['smoker'].value_counts()
# Out:
# no     1064
# yes     274
# Name: smoker, dtype: int64

# %%
#3.Region
plt.figure(figsize=(5,5))
sns.countplot(data['region'])
plt.title('Region')
plt.show()
# Out:
# /Users/Hanna/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.boxplot(x = 'region', y = 'charges', data = data)
plt.show()

# %%
data['region'].value_counts()
# Out:
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: region, dtype: int64

# %%
#relationship bewteen independent variables and dependent variables.

# %%
#See how charges change according to different ages and smoking status
age_charge = sns.lmplot(x ='age', y = 'charges', data = data, hue = 'smoker')

# %%
#See how charges change according to different bmi indexes and smoking status
bmi_charge = sns.lmplot(x ='bmi', y = 'charges', data = data, hue = 'smoker' )

# %%
sns.pairplot(data)

# %%
#Data Preprocessing
#Encoding'smoker'column
data.replace({'smoker':{'yes':0,'no':1}}, inplace=True)

# %%
#Encoding'sex'column
data.replace({'sex':{'male':0,'female':1}}, inplace=True)

# %%
#Encoding'region'column
data.replace({'region':{'southeast':1,'southwest':2,'northeast':3,'northwest':4}}, inplace=True)

# %%
data.head
# Out:
# <bound method NDFrame.head of       age  sex     bmi  children  smoker  region      charges
# 0      19    1  27.900         0       0       2  16884.92400
# 1      18    0  33.770         1       1       1   1725.55230
# 2      28    0  33.000         3       1       1   4449.46200
# 3      33    0  22.705         0       1       4  21984.47061
# 4      32    0  28.880         0       1       4   3866.85520
# ...   ...  ...     ...       ...     ...     ...          ...
# 1333   50    0  30.970         3       1       4  10600.54830
# 1334   18    1  31.920         0       1       3   2205.98080
# 1335   18    1  36.850         0       1       1   1629.83350
# 1336   21    1  25.800         0       1       2   2007.94500
# 1337   61    1  29.070         0       0       4  29141.36030
#
# [1338 rows x 7 columns]>

# %%
# Spliting The Data into Features and Target
X = data.drop('charges', axis = 1)
y = data['charges']

# %%
print(X)
# Out:
#       age  sex     bmi  children  smoker  region
# 0      19    1  27.900         0       0       2
# 1      18    0  33.770         1       1       1
# 2      28    0  33.000         3       1       1
# 3      33    0  22.705         0       1       4
# 4      32    0  28.880         0       1       4
# ...   ...  ...     ...       ...     ...     ...
# 1333   50    0  30.970         3       1       4
# 1334   18    1  31.920         0       1       3
# 1335   18    1  36.850         0       1       1
# 1336   21    1  25.800         0       1       2
# 1337   61    1  29.070         0       0       4
#
# [1338 rows x 6 columns]

# %%
print(y)
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %%
corr = data.corr()
plt.figure(figsize= (10, 10))
sns.heatmap(corr, annot=True, mask=np.triu(corr))
plt.title("Correlation of Variables")
plt.show()

# %% [markdown]
# Modeling

# %%
# Spliting into Train data and test data
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1003, 6)
# (335, 6)
# (1003,)
# (335,)

# %%
from sklearn.linear_model import LinearRegression   ## importing the model library

lr=LinearRegression()  ## importing the model object
lr.fit(X_train,y_train) ## fitting the training data

X_test_pred=lr.predict(X_test)

# %%
print(X_test_pred)
# Out:
# [ 8569.02792102  7226.24226101 37082.12596551  9704.40470976
#  27154.89445082 11099.50396214   287.75903995 17192.26142479
#    649.86159841 11475.04981963 28330.08174632  9614.31257617
#   5059.10380215 38318.60361415 40188.64744507 37002.33742225
#  15084.32748246 35750.87578953  8949.03881572 31635.73858748
#   4066.74697862 10388.4371046   2569.89417776  6682.25980692
#  11495.6971861  12580.08990064 14740.82601338  6299.0628445
#   9568.01685349  2011.8942882   9304.15869233 13280.99111107
#   4337.56975838  3555.02545142  4676.84319149 12693.94100914
#   2120.14150719  9005.52894884 33467.65638726 32462.62589045
#   4048.14515865  4516.4774556  14365.65205159 11701.01027073
#   8645.58566659 12392.84601145  5405.29550866  3302.36665877
#  35390.2179744   9016.67395506 15712.31509893  2178.67516687
#  12532.23586296  1080.70337419 13313.1736781  12249.76589852
#   3968.79155916 32378.52095891 13548.03772002 12512.8522698
# ...

# %%
X_train_pred=lr.predict(X_train)
print(X_train_pred)
# Out:
# [ 2015.33650199  4187.96503367 14429.94864686 ... 11134.584322
#  37492.03334939 11738.037071  ]

# %%
from sklearn.metrics import r2_score,mean_squared_error

# %%
training_num=r2_score(y_train,X_train_pred)
print('The Linear Regression training is :',training_num)
# Out:
# The Linear Regression training is : 0.7445275825163911

# %%
testing_num=r2_score(y_test,X_test_pred)
print('The Linear Regression testing is :',testing_num)
# Out:
# The Linear Regression testing is : 0.7667469908213232

# %%
print('MSE of training is :',mean_squared_error(y_train,X_train_pred))
print('MSE of testing is:',mean_squared_error(y_test,X_test_pred))
# Out:
# MSE of training is : 37066593.66259437
# MSE of testing is: 35195812.3944898

# %%
print('R^2 of training is :', r2_score(y_train,X_train_pred))
print('R^2 of testing is:', r2_score(y_test,X_test_pred))
# Out:
# R^2 of training is : 0.7445275825163911
# R^2 of testing is: 0.7667469908213232

# %%
print('RMSE of training is :', np.sqrt(mean_squared_error(y_train,X_train_pred)))
print('RMSE of testing is:', np.sqrt(mean_squared_error(y_test,X_test_pred)))
# Out:
# RMSE of training is : 6088.23403480799
# RMSE of testing is: 5932.605868797438

# %% [markdown]
# Residuals (Difference between y_test and y_pred)

# %%
y_pred = lr.predict(X_test)

# %%
test_residual= y_test - y_pred

# %%
print(y_test)
# Out:
# 764      9095.06825
# 887      5272.17580
# 890     29330.98315
# 1293     9301.89355
# 259     33750.29180
#            ...
# 342     13217.09450
# 308     11944.59435
# 1128    14358.36437
# 503     32548.34050
# 1197     5699.83750
# Name: charges, Length: 335, dtype: float64

# %%
print(y_pred)
# Out:
# [ 8569.02792102  7226.24226101 37082.12596551  9704.40470976
#  27154.89445082 11099.50396214   287.75903995 17192.26142479
#    649.86159841 11475.04981963 28330.08174632  9614.31257617
#   5059.10380215 38318.60361415 40188.64744507 37002.33742225
#  15084.32748246 35750.87578953  8949.03881572 31635.73858748
#   4066.74697862 10388.4371046   2569.89417776  6682.25980692
#  11495.6971861  12580.08990064 14740.82601338  6299.0628445
#   9568.01685349  2011.8942882   9304.15869233 13280.99111107
#   4337.56975838  3555.02545142  4676.84319149 12693.94100914
#   2120.14150719  9005.52894884 33467.65638726 32462.62589045
#   4048.14515865  4516.4774556  14365.65205159 11701.01027073
#   8645.58566659 12392.84601145  5405.29550866  3302.36665877
#  35390.2179744   9016.67395506 15712.31509893  2178.67516687
#  12532.23586296  1080.70337419 13313.1736781  12249.76589852
#   3968.79155916 32378.52095891 13548.03772002 12512.8522698
# ...

# %%
pd.DataFrame({'Actual': y_test, 'Predicted': y_pred, 'diff':(abs(y_test- y_pred))})
# Out:
#            Actual     Predicted         diff
# 764    9095.06825   8569.027921   526.040329
# 887    5272.17580   7226.242261  1954.066461
# 890   29330.98315  37082.125966  7751.142816
# 1293   9301.89355   9704.404710   402.511160
# 259   33750.29180  27154.894451  6595.397349
# ...           ...           ...          ...
# 342   13217.09450  12407.173239   809.921261
# 308   11944.59435  14400.524856  2455.930506
# 1128  14358.36437   7695.376058  6662.988312
# 503   32548.34050  25958.982415  6589.358085
# 1197   5699.83750   9126.299697  3426.462197
#
# [335 rows x 3 columns]

# %%
#residuals
sns.residplot(y_test, y_pred)  
plt.show()
# Out:
# /Users/Hanna/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#save the final model
final_model = LinearRegression()
final_model.fit(X_train,y_train)
dump(final_model, 'medical insurance')
# Out:
# ['medical insurance']

# %%
#load the model
load_model = load('medical insurance')

# %%
Input_Data=[[60, 1, 25.84, 0, 1, 3]]

# %%
load_model.predict(Input_Data)
# Out:
# /Users/Hanna/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([11830.83079134])
